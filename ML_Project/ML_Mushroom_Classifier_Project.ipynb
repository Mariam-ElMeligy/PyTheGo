# %%
# %pip install ucimlrepo
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
secondary_mushroom = fetch_ucirepo(id=848)

# data (as pandas dataframes)
X = secondary_mushroom.data.features
y = secondary_mushroom.data.targets

# metadata
print(secondary_mushroom.metadata)

# variable information
print(secondary_mushroom.variables)
# Out:
# {'uci_id': 848, 'name': 'Secondary Mushroom', 'repository_url': 'https://archive.ics.uci.edu/dataset/848/secondary+mushroom+dataset', 'data_url': 'https://archive.ics.uci.edu/static/public/848/data.csv', 'abstract': 'Dataset of simulated mushrooms for binary classification into edible and poisonous.', 'area': 'Biology', 'tasks': ['Classification'], 'characteristics': ['Tabular'], 'num_instances': 61068, 'num_features': 20, 'feature_types': ['Real'], 'demographics': [], 'target_col': ['class'], 'index_col': None, 'has_missing_values': 'yes', 'missing_values_symbol': 'NaN', 'year_of_dataset_creation': 2021, 'last_updated': 'Wed Apr 10 2024', 'dataset_doi': '10.24432/C5FP5Q', 'creators': ['Dennis Wagner', 'D. Heider', 'Georges Hattab'], 'intro_paper': {'ID': 259, 'type': 'NATIVE', 'title': 'Mushroom data creation, curation, and simulation to support classification tasks', 'authors': 'Dennis Wagner, D. Heider, Georges Hattab', 'venue': 'Scientific Reports', 'year': 2021, 'journal': None,
# ...

# %% [markdown]
# ### Mushroom Dataset Description
#
# **Target Variable (Binary Class):**
# - `edible = e`
# - `poisonous = p` (also includes mushrooms of unknown edibility)
#
# ---
#
# ### Features (20 variables: nominal = n, metrical = m)
#
# 1. **cap-diameter (m):** float number in cm
# 2. **cap-shape (n):**
#    - bell = b
#    - conical = c
#    - convex = x
#    - flat = f
#    - sunken = s
#    - spherical = p
#    - others = o
# 3. **cap-surface (n):**
#    - fibrous = i
#    - grooves = g
#    - scaly = y
#    - smooth = s
#    - shiny = h
#    - leathery = l
#    - silky = k
#    - sticky = t
#    - wrinkled = w
#    - fleshy = e
# 4. **cap-color (n):**
#    - brown = n
#    - buff = b
#    - gray = g
#    - green = r
#    - pink = p
#    - purple = u
#    - red = e
#    - white = w
#    - yellow = y
#    - blue = l
#    - orange = o
#    - black = k
# 5. **does-bruise-bleed (n):**
#    - bruises-or-bleeding = t
#    - no = f
# 6. **gill-attachment (n):**
#    - adnate = a
#    - adnexed = x
#    - decurrent = d
#    - free = e
#    - sinuate = s
#    - pores = p
#    - none = f
#    - unknown = ?
# 7. **gill-spacing (n):**
#    - close = c
#    - distant = d
#    - none = f
# 8. **gill-color (n):** see `cap-color` + none = f
# 9. **stem-height (m):** float number in cm
# 10. **stem-width (m):** float number in mm
# 11. **stem-root (n):**
#     - bulbous = b
#     - swollen = s
#     - club = c
#     - cup = u
#     - equal = e
#     - rhizomorphs = z
#     - rooted = r
# 12. **stem-surface (n):** see `cap-surface` + none = f
# 13. **stem-color (n):** see `cap-color` + none = f
# 14. **veil-type (n):**
#     - partial = p
#     - universal = u
# 15. **veil-color (n):** see `cap-color` + none = f
# 16. **has-ring (n):**
#     - ring = t
#     - none = f
# 17. **ring-type (n):**
#     - cobwebby = c
#     - evanescent = e
#     - flaring = r
#     - grooved = g
#     - large = l
#     - pendant = p
#     - sheathing = s
#     - zone = z
#     - scaly = y
#     - movable = m
#     - none = f
#     - unknown = ?
# 18. **spore-print-color (n):** see `cap-color`
# 19. **habitat (n):**
#     - grasses = g
#     - leaves = l
#     - meadows = m
#     - paths = p
#     - heaths = h
#     - urban = u
#     - waste = w
#     - woods = d
# 20. **season (n):**
#     - spring = s
#     - summer = u
#     - autumn = a
#     - winter = w
#
# ---
#
# ### Class Labels
# - **edible = e**
# - **poisonous = p**

# %%
X
# Out:
#        cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# 0             15.26         x           g         o                    f
# 1             16.60         x           g         o                    f
# 2             14.07         x           g         o                    f
# 3             14.17         f           h         e                    f
# 4             14.64         x           h         o                    f
# ...             ...       ...         ...       ...                  ...
# 61064          1.18         s           s         y                    f
# 61065          1.27         f           s         y                    f
# 61066          1.27         s           s         y                    f
# 61067          1.24         f           s         y                    f
# 61068          1.17         s           s         y                    f
#
#       gill-attachment gill-spacing gill-color  stem-height  stem-width  \
# ...

# %%
y
# Out:
#       class
# 0         p
# 1         p
# 2         p
# 3         p
# 4         p
# ...     ...
# 61064     p
# 61065     p
# 61066     p
# 61067     p
# 61068     p
#
# [61069 rows x 1 columns]

# %% [markdown]
# ## Mushroom Classification Project
#
# ### Problem Description
# The goal of this project is to classify mushrooms as **edible (e)** or **poisonous (p)** based on 20 descriptive features such as cap shape, cap color, stem characteristics, habitat, and season.
# This is a **binary classification problem** where the target variable is the mushroom class (`edible` or `poisonous`).
#
# ---
#
# ### Project Workflow
#
# #### 1. Exploratory Data Analysis (EDA)
# - Inspect the dataset structure (rows, columns, data types).
# - Check for missing values and duplicates.
# - Visualize distributions of categorical features (bar plots) and numeric features (histograms, boxplots).
# - Explore correlations between features and the target class.
# - Look for class imbalance in the target variable (edible vs poisonous).
#
# #### 2. Data Cleaning & Preprocessing
# - Handle missing values or unknown entries if present.
# - Encode categorical features (e.g., **One-Hot Encoding** or **Label Encoding**).
# - Scale numerical features (e.g., **StandardScaler** or **MinMaxScaler**).
# - Stratify the dataset when splitting into **training and test sets** to maintain class balance.
# - If class imbalance is significant, apply oversampling techniques (e.g., **SMOTE**).
#
# #### 3. Feature Selection
# To reduce dimensionality and improve generalization, apply feature selection techniques such as:
# - **Filter Methods:** Use statistical tests (e.g., Chi-square, ANOVA F-test, mutual information) to rank features.
# - **Wrapper Methods:** Apply Recursive Feature Elimination (**RFE**) with models like Logistic Regression or Decision Trees.
# - **Embedded Methods:** Leverage feature importance from models (e.g., Decision Tree, Random Forest, Lasso Regression).
# - Compare model performance before and after feature selection to evaluate impact.
#
# #### 4. Model Training & Evaluation
# Train and evaluate the following classification models:
# - **Logistic Regression**
# - **Decision Tree**
# - **Random Forest**
# - **Support Vector Machine (SVM)**
# - **K-Nearest Neighbors (KNN)**
# - **Naive Bayes**
#
# For each model:
# - Train on the **training set**.
# - Evaluate on the **test set** using:
#   - **Classification Report** (Precision, Recall, F1-score, Accuracy)
#   - **Confusion Matrix**
#   - **Cross-validation (optional)** for stability check
#
# #### 5. Hyperparameter Tuning
# To improve model performance, apply hyperparameter optimization techniques:
# - **Grid Search:** Exhaustively search all combinations of parameters (good for small parameter spaces).
# - **Random Search:** Randomly sample parameter combinations (more efficient for large parameter spaces).
# - **Bayesian Optimization:** Iteratively choose hyperparameters based on past performance (efficient for complex models like Random Forest, SVM, or KNN).
#
# Compare tuned models with baseline models to measure improvement.
#
# #### 6. Feature Importance
# - Extract **feature importance** from Decision Tree and Random Forest models.
# - Rank features to identify the most influential ones for classification.
# - Use feature importance as a basis for feature selection and model simplification.
#
# #### 7. Model Comparison
# - Compare performance across all models (baseline, tuned, and with feature selection).
# - Use metrics such as accuracy, precision, recall, F1-score, and ROC-AUC to decide the best-performing model.
# - Create plot of ROC-AUC curve of each model with different color for comparison
# - Summarize results in a **comparison table** or **bar plot**.
#
# ---
#
# #### 8. Save best models as pickle files
#
# ---
#
# ### Final Deliverables
# - Preprocessed dataset ready for classification.
# - Performance evaluation of six classification models.
# - Insights on class imbalance and handling techniques.
# - Feature selection results (filter, wrapper, and embedded methods).
# - Hyperparameter tuning results from Grid Search, Random Search, and Bayesian Optimization.
# - Feature importance ranking for better model interpretability.
# - Final comparison and recommendation of the best-performing model for mushroom classification.
# - pickle files of the saved models

# %%
# Necessary libraries:
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Handeling Warnings:
import warnings
from sklearn.exceptions import ConvergenceWarning
warnings.filterwarnings("ignore", category=FutureWarning, module="sklearn")
warnings.filterwarnings("ignore", category=ConvergenceWarning)

# Preprocessing and pipeline imports:
from scipy.stats import chi2_contingency
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import RobustScaler, OneHotEncoder, OrdinalEncoder, PowerTransformer
from sklearn.impute import SimpleImputer

# Imbalanced learning imports:
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline as ImbPipeline

# Model evaluation imports
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score

# Model imports
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

# Feature Selection Imports
from sklearn.feature_selection import SelectKBest, f_classif, mutual_info_classif
from sklearn.feature_selection import RFE
from sklearn.feature_selection import SelectFromModel

# HyperParameter Tuning imports
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# Comparasion and Evaluation imports
from sklearn.model_selection import learning_curve
from sklearn.metrics import roc_curve, auc

# Setting plotting style
plt.style.use('default')
sns.set_palette("husl")

# Saving To Pickle File
import pickle

# %% [markdown]
# ### **Phase 1: Data Understanding & Preparation**

# %% [markdown]
# #### 1) Data Loading & Initial Inspection

# %% [markdown]
# ##### 1. Inspecting Structure

# %%
df = pd.DataFrame(X)
df['target'] = y

df.head()
# Out:
#    cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# 0         15.26         x           g         o                    f
# 1         16.60         x           g         o                    f
# 2         14.07         x           g         o                    f
# 3         14.17         f           h         e                    f
# 4         14.64         x           h         o                    f
#
#   gill-attachment gill-spacing gill-color  stem-height  stem-width  ...  \
# 0               e          NaN          w        16.95       17.09  ...
# 1               e          NaN          w        17.99       18.19  ...
# 2               e          NaN          w        17.80       17.74  ...
# 3               e          NaN          w        15.77       15.98  ...
# 4               e          NaN          w        16.53       17.20  ...
#
#   stem-surface stem-color veil-type veil-color has-ring ring-type  \
# ...

# %%
print(f'''no of rows: {df.shape[0]}
no of columns: {df.shape[1]}''')
# Out:
# no of rows: 61069
# no of columns: 21

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61069 entries, 0 to 61068
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   cap-diameter          61069 non-null  float64
#  1   cap-shape             61069 non-null  object
#  2   cap-surface           46949 non-null  object
#  3   cap-color             61069 non-null  object
#  4   does-bruise-or-bleed  61069 non-null  object
#  5   gill-attachment       51185 non-null  object
#  6   gill-spacing          36006 non-null  object
#  7   gill-color            61069 non-null  object
#  8   stem-height           61069 non-null  float64
#  9   stem-width            61069 non-null  float64
#  10  stem-root             9531 non-null   object
#  11  stem-surface          22945 non-null  object
#  12  stem-color            61069 non-null  object
#  13  veil-type             3177 non-null   object
#  14  veil-color            7413 non-null   object
# ...

# %%
df.describe()
# Out:
#        cap-diameter   stem-height    stem-width
# count  61069.000000  61069.000000  61069.000000
# mean       6.733854      6.581538     12.149410
# std        5.264845      3.370017     10.035955
# min        0.380000      0.000000      0.000000
# 25%        3.480000      4.640000      5.210000
# 50%        5.860000      5.950000     10.190000
# 75%        8.540000      7.740000     16.570000
# max       62.340000     33.920000    103.910000

# %% [markdown]
# ##### 2. Handelling Duplicated Entries:

# %%
df.duplicated().sum()
# Out:
# np.int64(146)

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ##### 3. Checking for Missing Data

# %%
df.isnull().mean()* 100
# Out:
# cap-diameter             0.000000
# cap-shape                0.000000
# cap-surface             23.176797
# cap-color                0.000000
# does-bruise-or-bleed     0.000000
# gill-attachment         16.176157
# gill-spacing            41.137173
# gill-color               0.000000
# stem-height              0.000000
# stem-width               0.000000
# stem-root               84.592026
# stem-surface            62.574069
# stem-color               0.000000
# veil-type               94.785221
# veil-color              87.832182
# has-ring                 0.000000
# ring-type                4.055939
# spore-print-color       89.616401
# habitat                  0.000000
# season                   0.000000
# target                   0.000000
# dtype: float64

# %% [markdown]
# > Columns with very high missing (>60%) better be dropped, Since they are mostly empty and imputing them would add too much noise.
#
# > Moderate-missing categorical columns will be imputed

# %%
df.drop(columns=['stem-surface','stem-root','veil-color','spore-print-color','veil-type'], inplace=True)

# %% [markdown]
# #### 2) Exploratory Data Analysis (EDA)

# %% [markdown]
# ##### 1. Target Variable:

# %%
plt.figure(figsize=(5,5))
ax = sns.countplot(x="target", data=df)

# Add percentages on top of bars
total = len(df["target"])
for p in ax.patches:
    count = p.get_height()
    percentage = f'{100 * count / total:.1f}%'
    ax.annotate(percentage, (p.get_x() + p.get_width() / 2, count), 
                ha='center', va='bottom', fontsize=10, color='black', xytext=(0, 2), textcoords='offset points')

plt.title("Target Column Distribution with Percentages")
plt.xlabel("Target Classes")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

# %% [markdown]
# > The plot shows a mild imbalance between the two target classes -> `55.4%` to `44.6%`
# (not very severe to affect the classification, but might be worth addressing too)

# %% [markdown]
# ##### 2. Categorical Features:

# %% [markdown]
# **Checking Distributions -> Bar Plot**

# %%
categoricals = df.select_dtypes(include=['object']).columns.drop('target')

n_cols = 3
n_rows = (len(categoricals) + n_cols - 1) // n_cols

fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 5*n_rows))
axes = axes.flatten()

for i, col in enumerate(categoricals):
    df[col].value_counts().plot(kind='bar', ax=axes[i])
    axes[i].set_title(f'{col} Distribution')
    axes[i].set_xlabel(f"{col} Categories")
    axes[i].set_ylabel("Count")

for j in range(i+1,len(axes)):
    fig.delaxes(axes[j])  

plt.tight_layout()
plt.show()

# %% [markdown]
# > Many features include multiple categories which requires a careful approach towards encoding and introduces a need of importance inspection before modelling

# %% [markdown]
# **Assessing Relationship with Target -> Stacked Bar Plot / Caramer's V**

# %%
categoricals = df.select_dtypes(include=['object']).columns.drop('target')

n_cols = 3
n_rows = (len(categoricals) + n_cols - 1) // n_cols

fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 5*n_rows))
axes = axes.flatten()

for i, col in enumerate(categoricals):
    ct = pd.crosstab(df[col], df['target'])
    ct.plot(kind='bar', ax=axes[i])
    axes[i].set_title(f'{col} Distribution')
    axes[i].set_xlabel(f"{col} Categories")
    axes[i].set_ylabel("Count")

for j in range(i+1,len(axes)):
    fig.delaxes(axes[j])  

plt.tight_layout()
plt.show()

# %%
def cramers_v(x, y):
    """
    Calculate Cramér's V statistic for categorical-categorical association.
    """
    confusion_matrix = pd.crosstab(x, y)
    chi2 = chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    phi2 = chi2 / n
    r, k = confusion_matrix.shape

    # Bias correction
    phi2corr = max(0, phi2 - ((k-1)*(r-1))/(n-1))    
    rcorr = r - ((r-1)**2)/(n-1)
    kcorr = k - ((k-1)**2)/(n-1)
    return np.sqrt(phi2corr / min((kcorr-1), (rcorr-1)))


cramers_results = {}
for col in categoricals:
    cramers_results[col] = cramers_v(df[col], df['target'])

cramers_df = pd.DataFrame.from_dict(cramers_results, orient='index', columns=['Cramers_V'])
print(cramers_df.sort_values(by='Cramers_V', ascending=False))
# Out:
#                       Cramers_V
# stem-color             0.269571
# cap-surface            0.260179
# cap-color              0.241905
# gill-attachment        0.228996
# ring-type              0.202311
# gill-color             0.191280
# cap-shape              0.188697
# habitat                0.176850
# gill-spacing           0.145751
# season                 0.119169
# has-ring               0.058302
# does-bruise-or-bleed   0.018446

# %% [markdown]
# **Assessing Pair Wise Relationships -> Cramer's V**

# %%
categoricals = df.select_dtypes(include="object").columns

# Pairwise Cramér’s V
cramers_matrix = pd.DataFrame(
    np.zeros((len(categoricals), len(categoricals))),
    index=categoricals,
    columns=categoricals
)

for col1 in categoricals:
    for col2 in categoricals:
        if col1 == col2:
            cramers_matrix.loc[col1, col2] = 1.0  # self-correlation
        else:
            cramers_matrix.loc[col1, col2] = cramers_v(df[col1], df[col2])

plt.figure(figsize=(10,8))
sns.heatmap(cramers_matrix, annot=True, fmt=".2f", cmap="Blues")
plt.title("Cramer's V Correlation between Categorical Features")
plt.show()

# %% [markdown]
# > Since some features are some strongly Correlated pairs (more than ~70% multicolinearity), it's better to keep only one of each, Cramer's V between feature and target would act as a refrence to help choose which one to of the pair to keep
#
# > (e.g. `has-ring` & `ring-type` are highly correlated with ~87% multicolinearity, but `has-ring` is less correlated with target with only 6% colinearity compared to `ring-type` with 20% colinearity, hence `has-ring` will be the one to be dropped)

# %%
df.drop(columns=['gill-spacing','has-ring'], inplace=True)
df
# Out:
#        cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# 0             15.26         x           g         o                    f
# 1             16.60         x           g         o                    f
# 2             14.07         x           g         o                    f
# 3             14.17         f           h         e                    f
# 4             14.64         x           h         o                    f
# ...             ...       ...         ...       ...                  ...
# 61064          1.18         s           s         y                    f
# 61065          1.27         f           s         y                    f
# 61066          1.27         s           s         y                    f
# 61067          1.24         f           s         y                    f
# 61068          1.17         s           s         y                    f
#
#       gill-attachment gill-color  stem-height  stem-width stem-color  \
# ...

# %% [markdown]
# ##### 3. Numerical Features:

# %% [markdown]
# Checking Distribution (Assessing Skeweness) -> Histogram

# %%
plt.figure(figsize=(20, 5))

plt.subplot(1, 3, 1)
sns.histplot(df['cap-diameter'], bins=50, kde=True ,)
plt.title('Distribution of Cap Diameter')
plt.xlabel('Diameters')
plt.ylabel('Frequency')
plt.subplot(1, 3, 1)

plt.subplot(1, 3, 2)
sns.histplot(df['stem-height'], bins=50, kde=True)
plt.title('Distribution of Stem Height')
plt.xlabel('Heights')
plt.ylabel('Frequency')


plt.subplot(1, 3, 3)
sns.histplot(df['stem-width'], bins=50, kde=True)
plt.title('Distribution of Stem Widht')
plt.xlabel('Width')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# > Histograms show that features are heavely right-skewed with potential outliers

# %% [markdown]
# Checking Distributions (Assessing Outliers) -> Box Plot

# %%
plt.figure(figsize=(20, 5))

plt.subplot(1, 3, 1)
sns.boxplot(x='cap-diameter', data=df)
plt.title('Cap Diameter Distribution')
plt.xlabel('Diameter')

plt.subplot(1, 3, 2)
sns.boxplot(x='stem-height', data=df)
plt.title('Stem Height Distribution')
plt.xlabel('Height')

plt.subplot(1, 3, 3)
sns.boxplot(x='stem-width', data=df)
plt.title('Stem Width Distribution')
plt.xlabel('Width')

plt.show()

# %% [markdown]
# > Cap diameter outliers go up to ~60cm (More likely a mistake) -> Most edible/wild mushrooms range 2–25 cm.
#
# > Stem height outliers go up to ~35cm (Very tall for a mushroom, more likely a mis-entry) -> Common range is 2–15 cm, with some giants up to 20–30 cm.
#
# > Stem width outliers go up to ~110mm/~11cm (Hugely unrealistic for most species, Likely an error) -> Usually 0.5–3 cm (5–30 mm). A really thick one may hit ~50 mm, but 110 mm (11 cm) is extreme.

# %% [markdown]
# Checking Correlation:

# %%
# Encoding Target Variable:
df['target'] = df['target'].str.strip().map({'e': 1, 'p': 0})

# Checking Correaltion:
correlation = df.corr(numeric_only=True)

plt.figure(figsize=(10,5))
sns.heatmap(correlation, annot=True , fmt= '.2f', cmap= 'coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# > There's a strong Positive Correlation between `cap-diameter` and `stem-width` (~70%), which some domain insight might be derived from like: $$ Cap Stem Ratio = Cap Diameter / Stem Width $$

# %% [markdown]
# -----------------------

# %% [markdown]
# ### **Phase 2: Data Preprocessing & Splitting**

# %%
df
# Out:
#        cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# 0             15.26         x           g         o                    f
# 1             16.60         x           g         o                    f
# 2             14.07         x           g         o                    f
# 3             14.17         f           h         e                    f
# 4             14.64         x           h         o                    f
# ...             ...       ...         ...       ...                  ...
# 61064          1.18         s           s         y                    f
# 61065          1.27         f           s         y                    f
# 61066          1.27         s           s         y                    f
# 61067          1.24         f           s         y                    f
# 61068          1.17         s           s         y                    f
#
#       gill-attachment gill-color  stem-height  stem-width stem-color  \
# ...

# %% [markdown]
# #### 3) Data Splitting:

# %%
X = df.drop('target', axis=1)
y = df['target']

# Using stratify=y to ensure the class distribution is preserved in both sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %% [markdown]
# #### 4) Linear Preprocessor Object:
# Handling:
#
# > 'Missing Values' -> Imputer Obj
#
# > 'Outliers' -> Custom-Made Winsorizer Obj
#
# > 'Categorical-features' -> Encoder Obj
#
# > 'Numerical-Scale' -> Scaler Obj
#
# > 'Skewness' -> Transformer Obj

# %% [markdown]
# **Wisorizer Object:**

# %%
class Winsorizer(BaseEstimator, TransformerMixin):
    def __init__(self, lower=0.01, upper=0.99):
        self.lower = lower
        self.upper = upper
    
    def fit(self, X, y=None):
        # storing percentiles from training data
        self.lower_bounds = np.percentile(X, self.lower * 100, axis=0)
        self.upper_bounds = np.percentile(X, self.upper * 100, axis=0)
        return self
    
    def transform(self, X):
        # applying capping
        return np.clip(X, self.lower_bounds, self.upper_bounds)

# %%
num_features = ["cap-diameter", "stem-width", "stem-height"]
cat_features = df.select_dtypes(include=['object']).columns.tolist()

# Numerical pipeline
linear_num_pipeline = Pipeline([
    ("lin_imputer", SimpleImputer(strategy="median")),
    ("lin_winsor", Winsorizer(lower=0.01, upper=0.99)),       
    ("lin_scaler", RobustScaler()),                              
    ("lin_power", PowerTransformer(method='yeo-johnson')),    
])

# Categorical pipeline
linear_cat_pipeline = Pipeline([
    ("lin_imputer", SimpleImputer(strategy="most_frequent")),
    ("lin_encoder", OneHotEncoder(drop='first', handle_unknown="ignore", sparse_output=False)) 
])

# Full preprocessor 
linear_preprocessor = ColumnTransformer([
    ("lin_num", linear_num_pipeline, num_features),
    ("lin_cat", linear_cat_pipeline, cat_features)
])

# %% [markdown]
# #### 5) Tree-Based Preprocessor Object:
# Handling:
#
# > 'Missing Values' -> Imputer Obj
#
# > 'Categorical-features' -> Encoder Obj
#
# > 'Outliers' -> OPTIONAL

# %%
# Numerical pipeline 
tree_num_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy="median")),
    ("tree_winsor", Winsorizer(lower=0.01, upper=0.99)) 
])

# Categorical pipeline
tree_cat_pipeline = Pipeline([
    ("tree_imputer", SimpleImputer(strategy="most_frequent")),
    ("tree_encoder", OrdinalEncoder(handle_unknown="use_encoded_value", unknown_value=-1))
])

tree_preprocessor = ColumnTransformer([
    ("tree_num", tree_num_pipeline, num_features),
    ("tree_cat", tree_cat_pipeline, cat_features)
])

# %% [markdown]
# -------

# %% [markdown]
# ### **Phase 3: Modelling & Tuning**

# %% [markdown]
# #### 6) Baseline model performance results:

# %%
models = {
    'Logistic Regression': LogisticRegression(random_state=42, class_weight='balanced', max_iter=1000, solver='lbfgs'),
    'Decision Tree': DecisionTreeClassifier(random_state=42, class_weight='balanced'),
    'Random Forest': RandomForestClassifier(random_state=42, class_weight='balanced'),
    'SVM': LinearSVC(random_state=42, class_weight='balanced', max_iter=1000),
    'KNN': KNeighborsClassifier(),
    'Naive Bayes': GaussianNB()
}

models_needing_smote = ['KNN', 'Naive Bayes']
linear_models = ['Logistic Regression', 'SVM', 'KNN', 'Naive Bayes']

results = {} # To Store results of each classifier

#-----------------------------------------------------------------

for model_name, model in models.items():

    print(f"\n{'-'*50}")
    print(f"Training {model_name}")
    print(f"{'-'*50}")

    # Choosing appropriate preprocessor
    if model_name in linear_models:
        preprocessor = linear_preprocessor
    else:  
        preprocessor = tree_preprocessor

    # Pipeline with or without SMOTE
    if model_name in models_needing_smote:
        base_pipeline = ImbPipeline([
            ('preprocessor', preprocessor),
            ('smote', SMOTE(random_state=42)),
            ('classifier', model)
        ])
    else:
        base_pipeline = Pipeline([
            ('preprocessor', preprocessor),
            ('classifier', model)
        ])  

    # Training the model
    base_pipeline.fit(X_train, y_train)

    # Predictions
    y_pred = base_pipeline.predict(X_test)
    y_pred_proba = base_pipeline.predict_proba(X_test)[:, 1] if hasattr(base_pipeline, 'predict_proba') else None 

    # Evaluation
    print("\nClassification Report:")
    print(classification_report(y_test, y_pred))
    
    print("Confusion Matrix:")
    print(confusion_matrix(y_test, y_pred))
    print()
    # Cross Validation
    try:
        cv_scores = cross_val_score(base_pipeline, X_train, y_train, cv=5, scoring='f1_weighted')
        print(f"Cross-validation F1 scores: {cv_scores}")
        print(f"Mean CV F1: {cv_scores.mean():.3f} (±{cv_scores.std():.3f})")
    except Exception as e:
        print(f"Cross-validation failed: {e}")

    # Storing Results
    results[model_name] = {
        'pipeline': base_pipeline,
        'y_pred': y_pred,
        'y_pred_proba': y_pred_proba,
        'accuracy': accuracy_score(y_test, y_pred),
        'report': classification_report(y_test, y_pred, output_dict=True),
    }
    
#---------------------------------------------------------------------------------
# Out:
# --------------------------------------------------
# Training Logistic Regression
# --------------------------------------------------
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.76      0.79      6749
#            1       0.72      0.79      0.76      5436
#
#     accuracy                           0.77     12185
#    macro avg       0.77      0.78      0.77     12185
# weighted avg       0.78      0.77      0.77     12185
#
# Confusion Matrix:
# [[5103 1646]
#  [1115 4321]]
#
# Cross-validation F1 scores: [0.77766891 0.77834221 0.77650103 0.77318905 0.77879097]
# Mean CV F1: 0.777 (±0.002)
#
# --------------------------------------------------
# Training Decision Tree
# --------------------------------------------------
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      6749
# ...

# %% [markdown]
# ##### Comparing Baseline model performance:

# %%
print("\n" + "="*60)
print("Baseline Model Performance Comparasion")
print("="*60)

performance_data = []

for model_name, result in results.items():
    report = result['report']
    performance_data.append({
        'Model': model_name,
        'Accuracy': report['accuracy'],
        'Precision': report['weighted avg']['precision'],
        'Recall': report['weighted avg']['recall'],
        'F1-Score': report['weighted avg']['f1-score']
    })

performance_df = pd.DataFrame(performance_data)

# Sorting by F1
performance_df = performance_df.sort_values('F1-Score', ascending=False)

print(performance_df)
# Out:
# ...
# Baseline Model Performance Comparasion
# ...
#                  Model  Accuracy  Precision    Recall  F1-Score
# 2        Random Forest  0.998605   0.998605  0.998605  0.998605
# 4                  KNN  0.997948   0.997950  0.997948  0.997948
# 1        Decision Tree  0.993352   0.993352  0.993352  0.993352
# 3                  SVM  0.773738   0.779226  0.773738  0.774396
# 0  Logistic Regression  0.773410   0.777617  0.773410  0.774046
# 5          Naive Bayes  0.674108   0.713486  0.674108  0.669460

# %% [markdown]
# #### 7) Feature selection results and justification:

# %%
# Feature selection strategies dictionary for different models

feature_selection_strategies = {
    'Logistic Regression': {
        'method': 'rfe',
        'estimator': LogisticRegression(random_state=42, class_weight='balanced', max_iter=1000, solver='lbfgs'),
        'n_features': 30
    },
    'Decision Tree': {
        'method': 'embedded',
        'use_importance': True,
        'estimator' : DecisionTreeClassifier(random_state=42, class_weight='balanced'),
        'threshold': 'mean'  # Keeping only features above mean importance
    },
    'Random Forest': {
        'method': 'embedded', 
        'use_importance': True,
        'estimator' : RandomForestClassifier(random_state=42, class_weight='balanced'),
        'threshold': 0.01  # Keeping features with importance > 0.01
    },
    'SVM': {
        'method': 'rfe',
        'estimator': LinearSVC(random_state=42, class_weight='balanced', max_iter=1000),
        'n_features': 30
    },
    'KNN': {
        'method': 'filter',  
        'selector': SelectKBest(mutual_info_classif, k=30)
    },
    'Naive Bayes': {
        'method': 'filter',
        'selector': SelectKBest(f_classif, k=30)
    }
}

# %%
# Integrating feature selection in pipeline
def feature_selection_model_pipeline(model_name, model, preprocessor):
    
    strategy = feature_selection_strategies[model_name]
    
    if strategy['method'] == 'rfe':
        selector = RFE(
            estimator=strategy['estimator'],
            n_features_to_select=strategy['n_features']
        )
    elif strategy['method'] == 'embedded':
        selector = SelectFromModel(
        estimator=strategy['estimator'],
        threshold=strategy['threshold']
    )
    else: 
        selector = strategy['selector']
    
    # Pipeline
    if model_name in models_needing_smote:
        return ImbPipeline([
            ('preprocessor', preprocessor),
            ('feature_selector', selector),
            ('smote', SMOTE(random_state=42)),
            ('classifier', model)
        ])
    else:
        return Pipeline([
            ('preprocessor', preprocessor),
            ('feature_selector', selector),
            ('classifier', model)
        ])

# %%
fs_results = {}
for model_name, model in models.items():
    fs_pipeline = feature_selection_model_pipeline(model_name, model, preprocessor)
    fs_pipeline.fit(X_train, y_train)
    
    # Predictions
    y_pred_fs = fs_pipeline.predict(X_test)
    y_pred_proba_fs = fs_pipeline.predict_proba(X_test)[:, 1] if hasattr(fs_pipeline, 'predict_proba') else None

    fs_results[model_name] = {
        'pipeline': fs_pipeline,
        'y_pred': y_pred_fs,
        'y_pred_proba': y_pred_proba_fs,
        'accuracy': accuracy_score(y_test, y_pred_fs),
        'report': classification_report(y_test, y_pred_fs, output_dict=True),
    }

# %% [markdown]
# ##### Comparing Feature Selection Model Performance:

# %%
print("\n" + "="*60)
print("Feature Selection Model Performance Comparison")
print("="*60)

fs_performance_data = []

for model_name, result in fs_results.items():
    report = result['report']
    fs_performance_data.append({
        'Model': model_name,
        'Accuracy': report['accuracy'],
        'Precision': report['weighted avg']['precision'],
        'Recall': report['weighted avg']['recall'],
        'F1-Score': report['weighted avg']['f1-score']
    })

fs_performance_df = pd.DataFrame(fs_performance_data)

# Sorting by F1 score
fs_performance_df = fs_performance_df.sort_values('F1-Score', ascending=False)

print(fs_performance_df)
# Out:
# ...
# Feature Selection Model Performance Comparison
# ...
#                  Model  Accuracy  Precision    Recall  F1-Score
# 2        Random Forest  0.997948   0.997952  0.997948  0.997948
# 4                  KNN  0.989167   0.989170  0.989167  0.989168
# 1        Decision Tree  0.987936   0.987937  0.987936  0.987937
# 0  Logistic Regression  0.760279   0.762064  0.760279  0.760755
# 3                  SVM  0.752318   0.751994  0.752318  0.752120
# 5          Naive Bayes  0.609192   0.742691  0.609192  0.572605

# %%
# Creating a comprehensive comparison

comparison_df = performance_df.merge(
    fs_performance_df, on="Model", suffixes=("_Baseline", "_FS")
)

# Calculating differences
comparison_df['Accuracy_Diff'] = comparison_df['Accuracy_FS'] - comparison_df['Accuracy_Baseline']
comparison_df['F1-Score_Diff'] = comparison_df['F1-Score_FS'] - comparison_df['F1-Score_Baseline']
comparison_df['Precision_Diff'] = comparison_df['Precision_FS'] - comparison_df['Precision_Baseline']
comparison_df['Recall_Diff'] = comparison_df['Recall_FS'] - comparison_df['Recall_Baseline']

# Formatting the numbers 
for col in comparison_df.columns:
    if col != 'Model':
        comparison_df[col] = comparison_df[col].apply(lambda x: f"{x:.4f}")

# Sorting by performance impact (largest drop first)
comparison_df = comparison_df.sort_values('Accuracy_Diff')

print("\n" + "="*80)
print("BASELINE vs FEATURE SELECTION PERFORMANCE COMPARISON")
print("="*80)


print("\nPerformance Difference (FS - Baseline):")
print("-" * 80)
print(f"{'Model':<20} {'Accuracy':<12} {'F1-Score':<12} {'Precision':<12} {'Recall':<12}")
print("-" * 80)

for _, row in comparison_df.iterrows():
    print(f"{row['Model']:<20} {row['Accuracy_Diff']:<12} {row['F1-Score_Diff']:<12} {row['Precision_Diff']:<12} {row['Recall_Diff']:<12}")

print("-" * 80)

# Summary statistics
print("\nSummary Statistics: --> Recall")
print("-" * 40)
print(f"""* No. of models with improved Recall: {sum(comparison_df['Recall_Diff'].astype(float) >= 0)}/{len(comparison_df)}
* Average Recall change: {comparison_df['Recall_Diff'].astype(float).mean():.4f}
* Largest Recall improvement: {comparison_df['Recall_Diff'].astype(float).max():.4f}
* Largest Recall degradation: {comparison_df['Recall_Diff'].astype(float).min():.4f}""")

# Highlighting key findings
print("\n Key Findings:")
print("-" * 40)
best_fs_model = comparison_df.loc[comparison_df['Accuracy_FS'].astype(float).idxmax()]
worst_impact = comparison_df.loc[comparison_df['Accuracy_Diff'].astype(float).idxmin()]

print(f"* Best performing model with FS (Accuracy): {best_fs_model['Model']} ({best_fs_model['Accuracy_FS']})")
print(f"* Worst impact from FS (Accuracy): {worst_impact['Model']} ({worst_impact['Accuracy_Diff']} change)")
print(f"* Tree models (RF, DT) showed significant performance drop")
print(f"* Only linear models had modest changes")

# Insights
print("\n Insight:")
print("-" * 40)
print("""1. Feature selection overall degraded performance, As it's meant to help with overfitting and complexity, but base-line models weren't overfitting - they were generalizing well""")
print("2. Tree Models Don't Need Feature Selection, They work best with ALL features - they're robust to irrelevant features")
print("3. Distance-based models (e.g. KNN) Suffered from Information Loss, Removing features can eliminate important distance information")
# Out:
# ...
# BASELINE vs FEATURE SELECTION PERFORMANCE COMPARISON
# ...
#
# Performance Difference (FS - Baseline):
# --------------------------------------------------------------------------------
# Model                Accuracy     F1-Score     Precision    Recall
# --------------------------------------------------------------------------------
# Random Forest        -0.0007      -0.0007      -0.0007      -0.0007
# Decision Tree        -0.0054      -0.0054      -0.0054      -0.0054
# KNN                  -0.0088      -0.0088      -0.0088      -0.0088
# Logistic Regression  -0.0131      -0.0133      -0.0156      -0.0131
# SVM                  -0.0214      -0.0223      -0.0272      -0.0214
# Naive Bayes          -0.0649      -0.0969      0.0292       -0.0649
# --------------------------------------------------------------------------------
#
# Summary Statistics: --> Recall
# ----------------------------------------
# * No. of models with improved Recall: 0/6
# * Average Recall change: -0.0191
# ...

# %% [markdown]
# #### 8) Hyperparameter tuning results (best parameters for each model):

# %%
# Different tuning strategies for different models
tuning_strategies = {
    'Logistic Regression': {
        'method': 'grid',
        'params': {
            'classifier__C': [0.001, 0.01, 0.1, 1, 10, 100, 1000],
            'classifier__solver': ['lbfgs'],  # Simple and effective
            'classifier__penalty': ['l2'],    # Only compatible penalty
            'classifier__max_iter': [1000, 2000]
        },
        'n_iter': 10
    },
    'Decision Tree': {
        'method': 'grid',
        'params': {
            'classifier__max_depth': [None, 10, 20, 30, 50],
            'classifier__min_samples_split': [2, 5, 10],
            'classifier__min_samples_leaf': [1, 2, 4],
            'classifier__max_features': ['sqrt', 'log2', None]
        }
    },
    'Random Forest': {
        'method': 'random',
        'params': {
            'classifier__n_estimators': [200],
            'classifier__max_depth': [None],
            'classifier__min_samples_split': [5, 10],
            'classifier__min_samples_leaf': [1],
            'classifier__max_features': ['sqrt', 'log2'],
            'classifier__bootstrap': [False]
        },

    },
    'SVM': {
    'method': 'grid',
    'params': {
        'classifier__C': [10, 15, 20],  
        'classifier__loss': ['hinge'],          
        'classifier__tol': [1e-3, 1e-4, 1e-5],   
        'classifier__dual': [True],
        'classifier__max_iter': [10000]        
        },
    },
    'KNN': {
        'method': 'grid',
        'params': {
            'classifier__n_neighbors': [3, 5, 7],
            'classifier__weights': ['distance'],
            'classifier__p': [1] 
        }
    },
    'Naive Bayes': {
        'method': 'grid',
        'params': {
            'classifier__var_smoothing': [1e-9, 1e-8, 1e-7, 1e-6, 1e-5]
        }
    }
}

# %%
def tune_model(model_name, pipeline, X_train, y_train):

    strategy = tuning_strategies[model_name]
    
    if strategy['method'] == 'grid':
        tuner = GridSearchCV(
            pipeline,
            strategy['params'],
            cv=3,  # Fewer folds for speed
            scoring='f1_weighted',
            n_jobs=-1, # to utilize all CPU cores
            verbose=1
        )
    elif strategy['method'] == 'random':
        tuner = RandomizedSearchCV(
            pipeline,
            strategy['params'],
            cv=3,
            n_iter= 4,
            scoring='f1_weighted',
            n_jobs=-1,
            verbose=1,
            random_state=42
        )
    
    print(f"Tuning {model_name}...")
    tuner.fit(X_train, y_train)
    
    return tuner.best_estimator_, tuner.best_params_, tuner.best_score_

# %%
tuned_results = {}
best_params = {}

for model_name in models.keys():
    print(f"\n{'='*60}")
    print(f"Tuning {model_name}")
    print(f"{'='*60}")
    
    if model_name in linear_models:
        preprocessor = linear_preprocessor
    else:
        preprocessor = tree_preprocessor
    
    # Create pipeline (without feature selection since it hurt performance)
    if model_name in models_needing_smote:
        tuned_pipeline = ImbPipeline([
            ('preprocessor', preprocessor),
            ('smote', SMOTE(random_state=42)),
            ('classifier', models[model_name])
        ])
    else:
        tuned_pipeline = Pipeline([
            ('preprocessor', preprocessor),
            ('classifier', models[model_name])
        ])
    
    # Tuning the model
    try:
        best_estimator, best_param, best_score = tune_model(model_name, tuned_pipeline, X_train, y_train)
        
        # Evaluating on test set
        y_pred_tuned = best_estimator.predict(X_test)
        y_pred_proba_tuned = best_estimator.predict_proba(X_test)[:, 1] if hasattr(best_estimator, 'predict_proba') else None
        
        tuned_results[model_name] = {
            'estimator': best_estimator,
            'best_params': best_param,
            'best_cv_score': best_score,
            'test_accuracy': accuracy_score(y_test, y_pred_tuned),
            'test_f1': f1_score(y_test, y_pred_tuned, average='weighted'),
            'y_pred': y_pred_tuned,
            'y_pred_proba': y_pred_proba_tuned,
            'report': classification_report(y_test, y_pred_tuned, output_dict=True),
        }
        
        best_params[model_name] = best_param
        
        print(f" {model_name} tuning completed")
        print(f"   Best CV Score: {best_score:.4f}")
        print(f"   Test Accuracy: {tuned_results[model_name]['test_accuracy']:.4f}")
        
    except Exception as e:

        print(f"{model_name} tuning failed: {e}")
        
        # Using untuned model as fallback
        base_pipeline.fit(X_train, y_train)
        y_pred = base_pipeline.predict(X_test)
        tuned_results[model_name] = {
            'estimator': base_pipeline,
            'best_params': 'Tuning failed',
            'test_accuracy': accuracy_score(y_test, y_pred),
            'test_f1': f1_score(y_test, y_pred, average='weighted'),
            'report': classification_report(y_test, y_pred, output_dict=True),
        }
# Out:
# ...
# Tuning Logistic Regression
# ...
# Tuning Logistic Regression...
# Fitting 3 folds for each of 14 candidates, totalling 42 fits
#  Logistic Regression tuning completed
#    Best CV Score: 0.7781
#    Test Accuracy: 0.7737
#
# ...
# Tuning Decision Tree
# ...
# Tuning Decision Tree...
# Fitting 3 folds for each of 135 candidates, totalling 405 fits
#  Decision Tree tuning completed
#    Best CV Score: 0.9923
#    Test Accuracy: 0.9934
#
# ...
# Tuning Random Forest
# ...
# Tuning Random Forest...
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
#  Random Forest tuning completed
#    Best CV Score: 0.9988
#    Test Accuracy: 0.9991
#
# ...
# Tuning SVM
# ...
# Tuning SVM...
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
#  SVM tuning completed
#    Best CV Score: 0.7872
#    Test Accuracy: 0.7816
#
# ...
# Tuning KNN
# ...
# Tuning KNN...
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
#  KNN tuning completed
#    Best CV Score: 0.9986
#    Test Accuracy: 0.9983
#
# ...
# Tuning Naive Bayes
# ...

# %% [markdown]
# ##### Comparing Hyper Parameter Tuning Model Performance:

# %%
# Comparing tuned vs baseline performance
comparison_data = []
for model_name in models.keys():
    baseline_acc = results[model_name]['accuracy']  # Your baseline results
    tuned_acc = tuned_results[model_name]['test_accuracy']
    
    improvement = tuned_acc - baseline_acc
    improvement_pct = (improvement / baseline_acc) * 100
    
    comparison_data.append({
        'Model': model_name,
        'Baseline_Accuracy': baseline_acc,
        'Tuned_Accuracy': tuned_acc,
        'Improvement': improvement,
        'Improvement_%': improvement_pct
    })

comparison_df = pd.DataFrame(comparison_data).sort_values('Improvement', ascending=False)

# Display results
print("\n" + "="*80)
print("HYPERPARAMETER TUNING RESULTS")
print("="*80)
print(comparison_df.to_string(index=False))

# Visualize improvements
plt.figure(figsize=(12, 6))
x_pos = np.arange(len(comparison_df))
plt.bar(x_pos, comparison_df['Improvement_%'], alpha=0.7)
plt.xticks(x_pos, comparison_df['Model'], rotation=45, ha='right')
plt.xlabel('Model')
plt.ylabel('Improvement (%)')
plt.title('Percentage Improvement After Hyperparameter Tuning')
plt.tight_layout()
plt.show()
# Out:
# ...
# HYPERPARAMETER TUNING RESULTS
# ...
#               Model  Baseline_Accuracy  Tuned_Accuracy  Improvement  Improvement_%
#                 SVM           0.773738        0.781617     0.007879       1.018244
#       Random Forest           0.998605        0.999097     0.000492       0.049310
#                 KNN           0.997948        0.998277     0.000328       0.032895
# Logistic Regression           0.773410        0.773656     0.000246       0.031834
#       Decision Tree           0.993352        0.993352     0.000000       0.000000
#         Naive Bayes           0.674108        0.674108     0.000000       0.000000

# %%
# Identify the best performing model after tuning
best_model_name = comparison_df.loc[comparison_df['Tuned_Accuracy'].idxmax(), 'Model']
best_model = tuned_results[best_model_name]['estimator']
best_accuracy = comparison_df['Tuned_Accuracy'].max()

print(f"\nBEST MODEL AFTER TUNING: {best_model_name}")
print(f"   Accuracy: {best_accuracy:.4f}")
print(f"   Best Parameters: {tuned_results[best_model_name]['best_params']}")
# Out:
# BEST MODEL AFTER TUNING: Random Forest
#    Accuracy: 0.9991
#    Best Parameters: {'classifier__n_estimators': 200, 'classifier__min_samples_split': 5, 'classifier__min_samples_leaf': 1, 'classifier__max_features': 'sqrt', 'classifier__max_depth': None, 'classifier__bootstrap': False}

# %%
# Analyzing learning curves to check for overfitting (For the best model)
train_sizes, train_scores, test_scores = learning_curve(
    best_model, X_train, y_train,
    cv=3, scoring='f1', n_jobs=-1,
    train_sizes=np.linspace(0.1, 1.0, 5)
)

# Ploting the learning curves
plt.figure(figsize=(10, 6))
plt.plot(train_sizes, np.mean(train_scores, axis=1), 'o-', label='Training score')
plt.plot(train_sizes, np.mean(test_scores, axis=1), 'o-', label='Cross-validation score')
plt.xlabel('Training examples')
plt.ylabel('F1-Score')
plt.title(f'Learning Curves for {best_model_name}')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# > The Learning Curves show Good Fit, as Training score and validation score are both high + The gap between them is small, Hence, Model is well balanced.
#
# > The Training score and validation score are converging → good generalization

# %% [markdown]
# ---------

# %% [markdown]
# ### **Phase 4: Final Evaluation & Interpretation**

# %% [markdown]
# #### 9) Final Model Evaluation:

# %% [markdown]
# ##### **1. Comparison Table:**

# %%
def comparison_table_stacked(baseline_results, fs_results, tuned_results):

    comparison_data = []

    for model_name in baseline_results.keys():

        base = baseline_results.get(model_name, {})
        fs = fs_results.get(model_name, {})
        tuned = tuned_results.get(model_name, {})

        # Accuracy
        base_acc = base.get('accuracy', np.nan)
        fs_acc = fs.get('accuracy', np.nan)
        tuned_acc = tuned.get('test_accuracy', np.nan)

        # 1st Row
        comparison_data.append({
            'Model': model_name,
            'Metric': 'Accuracy',
            'Baseline': base_acc,
            'FS': fs_acc,
            'Tuned': tuned_acc,
            'Best': max(base_acc, fs_acc, tuned_acc)
        })

        #--------------------------------------------------

        # F1
        base_f1 = base.get('report', {}).get('weighted avg', {}).get('f1-score', np.nan)
        fs_f1 = fs.get('report', {}).get('weighted avg', {}).get('f1-score', np.nan)
        tuned_f1 = tuned.get('test_f1', np.nan)

        # 2nd row
        comparison_data.append({
            'Model': model_name,
            'Metric': 'F1-Score',
            'Baseline': base_f1,
            'FS': fs_f1,
            'Tuned': tuned_f1,
            'Best': max(base_f1, fs_f1, tuned_f1)
        })

        #--------------------------------------------------

        # Recall
        base_rec = base.get('report', {}).get('weighted avg', {}).get('recall', np.nan)
        fs_rec = fs.get('report', {}).get('weighted avg', {}).get('recall', np.nan)
        tuned_rec = tuned.get('report', {}).get('weighted avg', {}).get('recall', np.nan)

        # 3rd row
        comparison_data.append({
            'Model': model_name,
            'Metric': 'Recall',
            'Baseline': base_rec,
            'FS': fs_rec,
            'Tuned': tuned_rec,
            'Best': max(base_rec, fs_rec, tuned_rec)
        })

        #--------------------------------------------------

        # Precision
        base_pre = base.get('report', {}).get('weighted avg', {}).get('precision', np.nan)
        fs_pre = fs.get('report', {}).get('weighted avg', {}).get('precision', np.nan)
        tuned_pre = tuned.get('report', {}).get('weighted avg', {}).get('precision', np.nan)

        # 4th row
        comparison_data.append({
            'Model': model_name,
            'Metric': 'Precision',
            'Baseline': base_pre,
            'FS': fs_pre,
            'Tuned': tuned_pre,
            'Best': max(base_pre, fs_pre, tuned_pre)
        })

    return pd.DataFrame(comparison_data)


# Stacked table
comparison_df = comparison_table_stacked(results, fs_results, tuned_results)
comparison_df = comparison_df.sort_values(['Best', 'Metric'], ascending=[False, True], ignore_index=True)
comparison_df
# Out:
#                   Model     Metric  Baseline        FS     Tuned      Best
# 0         Random Forest   Accuracy  0.998605  0.997948  0.999097  0.999097
# 1         Random Forest     Recall  0.998605  0.997948  0.999097  0.999097
# 2         Random Forest  Precision  0.998605  0.997952  0.999097  0.999097
# 3         Random Forest   F1-Score  0.998605  0.997948  0.999097  0.999097
# 4                   KNN  Precision  0.997950  0.989170  0.998278  0.998278
# 5                   KNN   Accuracy  0.997948  0.989167  0.998277  0.998277
# 6                   KNN     Recall  0.997948  0.989167  0.998277  0.998277
# 7                   KNN   F1-Score  0.997948  0.989168  0.998276  0.998276
# 8         Decision Tree   Accuracy  0.993352  0.987936  0.993352  0.993352
# 9         Decision Tree     Recall  0.993352  0.987936  0.993352  0.993352
# 10        Decision Tree  Precision  0.993352  0.987937  0.993352  0.993352
# ...

# %% [markdown]
# ##### Insights:
# 1. Tree-based models dominate (Random Forest, KNN, Decision Tree)
# * Random Forest has the highest overall scores across Accuracy, Recall, and F1 (> 0.999)
# * KNN also performs very well (≈ 0.998) but slightly below Random Forest
# * Decision Tree is strong (≈ 0.993) but noticeably weaker than RF & KNN
# > Suggests ensemble methods (RF) and instance-based methods (KNN) are best suited for your dataset.
# ----
# 2. Linear models (SVM, Logistic Regression) perform moderately
# * Accuracy/F1 ≈ 0.77–0.78
# * Both SVM and Logistic Regression show marginal improvements when tuned but remain weaker than trees
# > Indicates the dataset is not linearly separable — trees capture complex decision boundaries better.
# ----
# 3. Naive Bayes underperforms significantly
# * Accuracy & Recall stuck at ≈ 0.67 (baseline & tuned)
# * F1 even lower (≈ 0.57–0.67)
# > Strong sign that the conditional independence assumption of Naive Bayes is violated in this dataset

# %% [markdown]
# ##### **2. ROC-AUC Curve Comparison:**

# %%
def plot_all_roc_curves(results_dicts, titles, y_test):

    n_sets = len(results_dicts)
    fig, axes = plt.subplots(1, n_sets, figsize=(6*n_sets, 6), sharey=True)

    for ax, results_dict, title in zip(axes, results_dicts, titles):
        colors = plt.colormaps.get_cmap("Set3")(np.linspace(0, 1, len(results_dict)))

        for (model_name, results), color in zip(results_dict.items(), colors):
            if 'y_pred_proba' in results and results['y_pred_proba'] is not None:
                fpr, tpr, _ = roc_curve(y_test, results['y_pred_proba'])
                roc_auc = auc(fpr, tpr)

                ax.plot(fpr, tpr, color=color, lw=2,
                        label=f'{model_name} (AUC = {roc_auc:.3f})')

        # Reference line (Random Guess)
        ax.plot([0, 1], [0, 1], 'k--', lw=1.5)

        # Formatting
        ax.set_xlim([0.0, 1.0])
        ax.set_ylim([0.0, 1.05])
        ax.set_xlabel("False Positive Rate", fontsize=12)
        ax.set_ylabel("True Positive Rate", fontsize=12 if ax == axes[0] else 0)  
        ax.set_title(title, fontsize=14, fontweight="bold")
        ax.legend(loc="lower right", fontsize=9)
        ax.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()


# Usage
plot_all_roc_curves(
    results_dicts=[results, fs_results, tuned_results],
    titles=["Baseline Models", "With Feature Selection", "Tuned Models"],
    y_test=y_test
)

# %% [markdown]
# ##### Insights:
#
# 1. Feature Selection (FS) effects:
# * FS generally hurts performance for almost all models
# > Suggests that all or most features are informative; aggressive filtering removes useful signals.
# ----
# 2. Tuning effects:
# * Tuning almost always brings small improvements compared to baseline
# * For top models (Random Forest, KNN), tuning doesn’t add much (they’re already near-perfect)
# > Tuning helps weaker models more (SVM, Logistic Regression) but isn’t critical for strong models.

# %% [markdown]
# ##### **3. Bar plots for Metrics Comparison:**

# %%
def plot_metrics_comparison_stacked(comparison_df):
    """Bar plots for Accuracy, F1, Recall, and Precision comparisons"""
    
    metrics = ["Accuracy", "F1-Score", "Recall", "Precision"]
    n_metrics = len(metrics)
    
    fig, axes = plt.subplots(2, 2, figsize=(18, 13))
    axes = axes.flatten()
    
    palette = sns.color_palette("Set2", 3)  # 3 colors for Baseline, FS, Tuned
    
    for i, metric in enumerate(metrics):
        ax = axes[i]
        subset = comparison_df[comparison_df["Metric"] == metric]
        
        models = subset["Model"].values
        x = np.arange(len(models))
        width = 0.25
        
        ax.bar(x - width, subset["Baseline"], width, label="Baseline", color=palette[0], alpha=0.85)
        ax.bar(x, subset["FS"], width, label="With FS", color=palette[1], alpha=0.85)
        ax.bar(x + width, subset["Tuned"], width, label="Tuned", color=palette[2], alpha=0.85)
        
        # Formatting
        ax.set_title(f"{metric} Comparison", fontsize=14, fontweight="bold")
        ax.set_xticks(x)
        ax.set_xticklabels(models, rotation=30, ha="right", fontsize=11)
        ax.set_ylabel(metric)
        ax.grid(True, axis="y", alpha=0.3)
        ax.legend()
        
    plt.suptitle("Model Performance Comparison Across Metrics", fontsize=16, fontweight="bold")
    plt.tight_layout(rect=[0, 0, 1, 0.97])
    plt.show()

plot_metrics_comparison_stacked(comparison_df)

# %% [markdown]
# ##### Key Takeways:
#
# > 1. Best overall model: Random Forest (near-perfect metrics).
#
# > 2. Strong Candidate: KNN, slightly weaker but still excellent.
#
# > 3. Honourable Mention: Decision Tree is solid but less stable than RF → use ensembles.
#
# > 4. Weaker models: SVM & Logistic Regression.
#
# > 5. Worst model: Naive Bayes (bad fit for this dataset).
#
# * FS not useful here — the dataset benefits from using all features.
#
# * Tuning helps mainly for weaker learners, not for strong tree-based models.

# %%
def identify_best_models(comparison_df):

    # Focusing only on Recall for model comparison (most important metric based on data context)
    rec_df = comparison_df[comparison_df["Metric"] == "Recall"]

    best_overall = rec_df.loc[rec_df["Best"].idxmax()]

    best_baseline = rec_df.loc[rec_df["Baseline"].idxmax()]
    best_fs = rec_df.loc[rec_df["FS"].idxmax()]
    best_tuned = rec_df.loc[rec_df["Tuned"].idxmax()]

    print("="*60)
    print("BEST MODEL ANALYSIS (Recall)")
    print("-"*60)
    print(f"* Overall Best Model: {best_overall['Model']} ({best_overall['Best']:.4f})")
    print(f"* Best Baseline: {best_baseline['Model']} ({best_baseline['Baseline']:.4f})")
    print(f"* Best with Feature Selection: {best_fs['Model']} ({best_fs['FS']:.4f})")
    print(f"* Best Tuned: {best_tuned['Model']} ({best_tuned['Tuned']:.4f})")
    print("="*60)

    # Improvement analysis (Baseline vs Tuned)
    print("\nIMPROVEMENT ANALYSIS (Baseline → Tuned):")
    print("-"*60)
    for _, row in rec_df.iterrows():
        improvement = row["Tuned"] - row["Baseline"]
        print(f"{row['Model']}: {improvement:+.4f}")
    return best_overall["Model"]

best_model_name = identify_best_models(comparison_df)
# Out:
# ...
# BEST MODEL ANALYSIS (Recall)
# ------------------------------------------------------------
# * Overall Best Model: Random Forest (0.9991)
# * Best Baseline: Random Forest (0.9986)
# * Best with Feature Selection: Random Forest (0.9979)
# * Best Tuned: Random Forest (0.9991)
# ...
#
# IMPROVEMENT ANALYSIS (Baseline → Tuned):
# ------------------------------------------------------------
# Random Forest: +0.0005
# KNN: +0.0003
# Decision Tree: +0.0000
# SVM: +0.0079
# Logistic Regression: +0.0002
# Naive Bayes: +0.0000

# %% [markdown]
# #### 10) Feature importance ranking and plot

# %%
# Assessing Feature Importance for Best Performer (Random Forest)
best_model_name = 'Random Forest'  
best_pipeline = tuned_results[best_model_name]['estimator']

# Extracting the trained Random Forest model
rf_model = best_pipeline.named_steps['classifier']

# feature importances
feature_importances = rf_model.feature_importances_
feature_names = num_features + cat_features

# importance dataframe
importance_df = pd.DataFrame({
    'feature': feature_names,
    'importance': feature_importances
}).sort_values('importance', ascending=True)

# Calculating cumulative importance
importance_df['cumulative_importance'] = importance_df['importance'].cumsum()

# %%
plt.figure(figsize=(15, 6))

# Plot 1: Feature Importance
plt.subplot(1, 2, 1)
top_features = importance_df.sort_values('importance')
plt.barh(top_features['feature'], top_features['importance'])
plt.xlabel('Feature Importance')
plt.ylabel('Features')
plt.title('Feature Importance For Best Model\n(Random Forest)')
plt.grid(True, alpha=0.3, axis='x')

# Plot 2: Cumulative Importance 
plt.subplot(1, 2, 2)
plt.plot(range(1, len(importance_df) + 1), importance_df['cumulative_importance'], 'b-', linewidth=2)
plt.axhline(y=0.8, color='r', linestyle='--', alpha=0.7, label='80% Importance')
plt.axhline(y=0.9, color='g', linestyle='--', alpha=0.7, label='90% Importance')
plt.xlabel('Number of Features')
plt.ylabel('Cumulative Importance')
plt.title('Cumulative Feature Importance')
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# > The Feature Importance of the best performer Random Forest Shows that the top 5 most informative features (that hold the most predictive power) to help determine whether a Mushroom is poisonous or edible `stem-width`, `cap-surface`, `stem-height`, `stem-color` and `gill-attachement`.
#
# > The Cumulative Feature Importance plot shows that nearly all 13 features of data are informative and the interactivity between them adds value, hence, a model gets the most valuable info and the greatest predictive power once it trains on full feature space, thats why feature selection kind of hurt the performance instead of improving it.

# %% [markdown]
# ##### Final Take:
#
# “Tree-based methods, particularly `Random Forest`, provide near-perfect performance, suggesting the dataset’s patterns are highly non-linear and complex.
#
# Feature selection reduces performance, implying that most features contribute useful information. While tuning slightly improves linear models like SVM and Logistic Regression, these remain substantially weaker compared to ensemble and instance-based methods.”

# %% [markdown]
# ### **Phase 5: Pickle files of the saved model and preprocessing pipeline:**

# %%
best_pipeline
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('tree_num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('tree_winsor',
#                                                                    Winsorizer())]),
#                                                   ['cap-diameter', 'stem-width',
#                                                    'stem-height']),
#                                                  ('tree_cat',
#                                                   Pipeline(steps=[('tree_imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('tree_encoder',
# ...

# %%
# Saving the complete pipeline (includes preprocessing + model)
with open('best_mushroom_model.pkl', 'wb') as f:
    pickle.dump(best_pipeline, f)

# Load
with open("best_mushroom_model.pkl", "rb") as f:
    loaded_pipeline = pickle.load(f)

# %%
# Saving preprocessor and model separately
preprocessor = best_pipeline.named_steps['preprocessor']

with open("mushroom_preprocessor.pkl", "wb") as f:
    pickle.dump(preprocessor, f)

with open("mushroom_model.pkl", "wb") as f:
    pickle.dump(rf_model, f)

# %%
# Deployment package dictionary
deployment_package = {
    'model': model,
    'preprocessor': preprocessor,
    'description': 'Mushroom edibility classification model'
}

with open("mushroom_deployment_package.pkl", "wb") as f:
    pickle.dump(deployment_package, f)

# %%
import pickle
import pandas as pd

# Load preprocessor and model
with open("best_mushroom_model.pkl", "rb") as f:
    model = pickle.load(f)

# Example: new mushroom data (raw features)
new_data = pd.DataFrame([{
    "cap-diameter": 5.5,
    "stem-width": 1.2,
    "stem-height": 6.0,
    "cap-shape": "x",
    "cap-surface": "s",
    "cap-color": "n",
    "does-bruise-or-bleed": "t",
    "gill-attachment": "f",
    "gill-color": "k",
    "stem-color": "w",
    "ring-type": "p",
    "habitat": "g",
    "season": "s"
}])

# Preprocess + Predict
prediction = model.predict(new_data)

print("Prediction:", "Edible" if prediction[0] == 0 else "Poisonous")
# Out:
# Prediction: Edible
